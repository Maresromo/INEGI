# %%
import pandas as pd
import matplotlib.pyplot as plt
 # usecols = ['edu_ini','asis_esc','nivel','grado']

# %%
f = '../data/raw/1_enut_2024_bd_csv/tvivienda.csv'
TVIVIENDA = pd.read_csv(f,
                       # usecols = ['CVEGEO','LLAVEVIV']
                      )
TVIVIENDA
# Out:
#         LLAVEVIV  P1_1  P1_2  P1_3  P1_3A  P1_4  P1_5  P1_6  P1_7  P1_8  ...  \
# 0       10009401     2     1     2      2     1   1.0   NaN     1     1  ...
# 1       10009402     3     2     2      2     1   1.0   NaN     1     1  ...
# 2       10009403     3     1     1      3     1   1.0   NaN     1     1  ...
# 3       10009404     3     1     1      2     1   1.0   NaN     1     1  ...
# 4       10009405     3     1     2      2     1   1.0   NaN     1     1  ...
# ...          ...   ...   ...   ...    ...   ...   ...   ...   ...   ...  ...
# 28709  326035516     3     1     2      4     1   1.0   NaN     1     1  ...
# 28710  326048702     2     1     2      4     1   1.0   NaN     1     1  ...
# 28711  326089616     2     1     3      4     1   2.0   NaN     1     1  ...
# 28712  326103808     2     1     1      2     1   1.0   NaN     1     1  ...
# 28713  326123107     2     2     1      2     1   1.0   NaN     1     1  ...
#
#        P2_3  CVEGEO  CVE_ENT  TLOC  MENOR10  EST_DIS  UPM_DIS  FAC_VIV  \
# 0       NaN       1        1     1        2        1        1      509
# 1       NaN       1        1     1        2        1        1      509
# 2       NaN       1        1     1        2        1        1      509
# 3       NaN       1        1     1        2        1        1      509
# 4       NaN       1        1     1        2        1        1      509
# ...     ...     ...      ...   ...      ...      ...      ...      ...
# 28709   NaN      32       32     4        1      342     4196      444
# 28710   2.0      32       32     4        1      342     4197      575
# 28711   NaN      32       32     4        1      342     4200      503
# 28712   NaN      32       32     4        1      342     4204      546
# 28713   NaN      32       32     4        1      342     4208      573
#
#        CONTROL  VIV_SEL
# 0       100094        1
# 1       100094        2
# 2       100094        3
# 3       100094        4
# 4       100094        5
# ...        ...      ...
# 28709  3260355       16
# 28710  3260487        2
# 28711  3260896       16
# 28712  3261038        8
# 28713  3261231        7
#
# [28714 rows x 38 columns]

# %%
TVIVIENDA.columns
# Out:
# Index(['LLAVEVIV', 'P1_1', 'P1_2', 'P1_3', 'P1_3A', 'P1_4', 'P1_5', 'P1_6',
#        'P1_7', 'P1_8', 'P1_9', 'P1_10', 'P1_11', 'P1_12', 'P1_13', 'P1_14',
#        'P1_15_01', 'P1_15_02', 'P1_15_03', 'P1_15_04', 'P1_15_05', 'P1_15_06',
#        'P1_15_07', 'P1_15_08', 'P1_15_09', 'P1_15_10', 'P2_1', 'P2_2', 'P2_3',
#        'CVEGEO', 'CVE_ENT', 'TLOC', 'MENOR10', 'EST_DIS', 'UPM_DIS', 'FAC_VIV',
#        'CONTROL', 'VIV_SEL'],
#       dtype='object')

# %%
f = '../data/raw/1_enut_2024_bd_csv/tmodulo.csv'
prueba = pd.read_csv(f,
                       # usecols = ['CVEGEO','LLAVEVIV']
                      )
prueba.columns
# Out:
# Index(['LLAVEMOD', 'LLAVEVIV', 'LLAVEHOG', 'SEXO', 'EDAD_V', 'P4_1', 'P4_1C',
#        'NIV', 'GRA', 'P4_3',
#        ...
#        'CVE_ENT', 'TLOC', 'MENOR10', 'EST_DIS', 'UPM_DIS', 'FAC_PER',
#        'CONTROL', 'VIV_SEL', 'HOGAR', 'N_REN'],
#       dtype='object', length=694)
